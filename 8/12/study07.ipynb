# %%
# !mkdir common

# %%
# %%writefile common/utils.py

def add(num1:int, num2:int)-> int:
    return num1 + num2

def sub(num1:int, num2:int) -> int:
    return num1 - num2
# Out:
# Writing common/utils.py

# %%
from common.ai.ml import get_model  # 주피터 파일은 한번 import를 하면 다시 import하지 않음->restart를 하면 가능 * 하지 말기

# %%
get_model()
# Out:
# 'Qwen Model'
