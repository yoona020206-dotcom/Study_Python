# %% [markdown]
# # datetime

# %%
from datetime import datetime

# %%
# now : 객체
now = datetime.now() # y, m, d, hh, mm, ss, mt)
now
# Out:
# datetime.datetime(2026, 8, 13, 11, 21, 41, 509326)

# %%
now.year, now. month, now.hour, now.minute, now.second, now.microsecond
# Out:
# (2026, 8, 11, 21, 41, 509326)

# %%
# 날짜만
now.date()
# Out:
# datetime.date(2026, 8, 13)

# %%
# 시간만
now.time()
# Out:
# datetime.time(11, 21, 41, 509326)

# %%
# 0= mon, 1= tue, 2= wen, 3 = thr, 4 = fri, 5 = sat 6 = sun
now.weekday()
# Out:
# 3

# %%
# 시간을 포멧 한다 스트링으로 
now.strftime("%A %d. %B %Y")
# Out:
# 'Thursday 13. August 2026'

# %%
now.strftime("%Y-%m-%d %H:%M")
# Out:
# '2026-08-13 11:21'

# %%
type(now.strftime("%Y-%m-%d %H:%M"))
# Out:
# str

# %%
type(now)
# Out:
# datetime.datetime

# %%
str_datetime ='2026-08-13 11:21'
str_datetime
# Out:
# '2026-08-13 11:21'

# %%
datetime.strptime(str_datetime, "%Y-%m-%d %H:%M")
# Out:
# datetime.datetime(2026, 8, 13, 11, 21)

# %%
datetime.strptime(str_datetime, "%Y-%m-%d %H:%M").year
# Out:
# 2026

# %%
# 연산 (몇일 남있는지)
from datetime import datetime, timedelta

# %%
dt1 = datetime(2016, 2, 19, 14)
dt2= datetime(2016, 1, 2, 13)
dt1
# Out:
# datetime.datetime(2016, 2, 19, 14, 0)

# %%
td= dt1 - dt2
td
# Out:
# datetime.timedelta(days=48, seconds=3600)

# %%
# 현제시간 
now = datetime.now()

now
# Out:
# datetime.datetime(2026, 8, 13, 11, 37, 51, 615860)

# %%
diff = timedelta(days=1, hours=3, minutes=30)

diff
# Out:
# datetime.timedelta(days=1, seconds=12600)

# %%
now - diff
# Out:
# datetime.datetime(2026, 8, 12, 8, 7, 51, 615860)

# %%
from dateutil.parser import parse

# %%
parse('2026-08-13 11:21')
# Out:
# datetime.datetime(2026, 8, 13, 11, 21)
